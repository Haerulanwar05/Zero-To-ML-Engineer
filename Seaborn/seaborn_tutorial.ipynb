# %%
# import library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
# distribution plot

sns.distplot(crash_df['not_distracted'], kde=False, bins=25)
# Out:
# C:\Users\Haerul\AppData\Local\Temp\ipykernel_15936\186491436.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'], kde=False, bins=25)
# <Axes: xlabel='not_distracted'>

# %%
# Joint Plot

sns.jointplot(x='speeding', y='alcohol', kind='hex', data=crash_df)

# %%
# KDE Plot
sns.kdeplot(crash_df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
# Pair Plots

sns.pairplot(crash_df)

# %%
# Pair Plots
tips_df = sns.load_dataset('tips')
sns.pairplot(tips_df, hue='sex', palette='Blues')

# %%
# rug plot

sns.rugplot(tips_df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
# styling
sns.set_style('ticks')

plt.figure(figsize=(8,4))

sns.set_context('paper', font_scale=1.5)

sns.jointplot(x='speeding',y='alcohol', data=crash_df, kind='reg')

# %%
# categorical plots

# Bar Plots
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.cov)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# Count Plot
sns.countplot(x='sex', data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
type(tips_df)
# Out:
# pandas.DataFrame

# %%
mart = pd.read_excel("supermarket_sales.xlsx")
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %%
sns.countplot(x="Payment", data=mart)
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
mart.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   str
#  1   Branch                   1000 non-null   str
#  2   City                     1000 non-null   str
#  3   Customer type            1000 non-null   str
#  4   Gender                   1000 non-null   str
#  5   Product line             1000 non-null   str
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   str
#  13  cogs                     1000 non-null   float64
# ...

# %%
plt.figure(figsize=(15,5))


sns.countplot(x='Product line', data=mart, hue='Product line') # jika kode hanya ini aja, yes berfungsi namun tulisan di x bertabrakan
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
sns.countplot(y='Product line', data=mart, hue='Product line') # untuk mengubah menjadi horizontal kita tinggal ubah saja dari x ke y untuk parameter nya
# Out:
# <Axes: xlabel='count', ylabel='Product line'>

# %%
plt.figure(figsize=(15,7))

sns.countplot(x='Product line', data=mart, hue='Gender', palette='tab20')
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
plt.figure(figsize=(15,7))

sns.barplot(
    data=mart, 
    x="Product line", 
    y="Total", 
    hue="Product line", 
    palette=sns.color_palette("husl", 6),
    legend=False  # <-- Menghilangkan legenda yang redundan
)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))

sns.countplot(x='Product line', data=mart
            ,facecolor= (0,0,0,0)
            ,linewidth=5
            ,edgecolor=sns.color_palette('dark',3))
# Out:
# <Axes: xlabel='Product line', ylabel='count'>

# %%
# dataset yang sudah ada di seaborn 
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# jika kita mau mengambil dataset titanic
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
mart.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   str
#  1   Branch                   1000 non-null   str
#  2   City                     1000 non-null   str
#  3   Customer type            1000 non-null   str
#  4   Gender                   1000 non-null   str
#  5   Product line             1000 non-null   str
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   str
#  13  cogs                     1000 non-null   float64
# ...

# %%
plt.figure(figsize=(15,7))

sns.barplot(x='Product line',y='Total',hue='Gender', data=mart,order=['Electronic_accessories',    'Fashion_accessories',     'Food_and_beverages',
                                                                      'Health_and_beauty',     'Home_and_lifestyle',      'Sports_and_travel'],hue_order=['Male','Female'])



# membuat sebuah order nya berdasarkan alfabet dari a-z
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
x=mart['Product line'].sort_values()
x.unique()
# Out:
# <StringArray>
# ['Electronic_accessories',    'Fashion_accessories',     'Food_and_beverages',
#       'Health_and_beauty',     'Home_and_lifestyle',      'Sports_and_travel']
# Length: 6, dtype: str

# %%
# menjadi horizontal
sns.barplot(x='Total',y='Product line',hue='Gender', data=mart,order=['Electronic_accessories',    'Fashion_accessories',     'Food_and_beverages',
                                                                      'Health_and_beauty',     'Home_and_lifestyle',      'Sports_and_travel'],hue_order=['Male','Female'])
# Out:
# <Axes: xlabel='Total', ylabel='Product line'>

# %%
plt.figure(figsize=(15,7))

sns.barplot(x='Product line',y='Total',hue='Gender', data=mart,order=['Electronic_accessories',    'Fashion_accessories',     'Food_and_beverages',
                                                                      'Health_and_beauty',     'Home_and_lifestyle',      'Sports_and_travel'],hue_order=['Male','Female'],errorbar=None,palette='grey')



# membuat sebuah order nya berdasarkan alfabet dari a-z
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
# Menampilkan semua nama palet / colormap yang ada
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'berlin', 'managua', 'vanimo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'okabe_ito', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight
# ...

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',data=mart,hue='Gender',order=['Electronic_accessories',    'Fashion_accessories',     'Food_and_beverages',
                                                                      'Health_and_beauty',     'Home_and_lifestyle',      'Sports_and_travel'],errorbar=None,palette='twilight')
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',data=mart,hue='Gender',order=['Electronic_accessories',    'Fashion_accessories',     'Food_and_beverages',
                                                                      'Health_and_beauty',     'Home_and_lifestyle',      'Sports_and_travel'],errorbar=None,palette='twilight',saturation=0.5)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>

# %%
# estimator = aritmatika


plt.figure(figsize=(15,5))
sns.barplot(x='Product line',y='Total',data=mart,hue='Gender',order=['Electronic_accessories',    'Fashion_accessories',     'Food_and_beverages',
                                                                      'Health_and_beauty',     'Home_and_lifestyle',      'Sports_and_travel'],palette='twilight',saturation=0.5,estimator=np.median,errorbar=None)
# Out:
# <Axes: xlabel='Product line', ylabel='Total'>
