# %%
# import library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts

# %%
mart = pd.read_csv('train.xlsx').sample(50)
mart['Tier']=mart['Outlet_Location_Type'].str.split(expand=True)[1]

# %%
mart.head()
# Out:
#    Item_ID     Item_W     Item_Type    Item_MRP Outlet_ID  Outlet_Year  \
# 23   NCB18   9.724812     Household  132.102360    OUT013         2009
# 10   FDB12  18.910416   Soft Drinks  142.227475    OUT018         2004
# 4    FDX04  10.824812   Snack Foods  264.673302    OUT035         2004
# 5    FDR16   9.827295   Hard Drinks  156.443152    OUT035         2004
# 38   NCT06   9.811619  Frozen Foods  238.234059    OUT049         2004
#
#    Outlet_Size Outlet_Location_Type        Sales Tier
# 23       Small               Tier 2   262.489019    2
# 10      Medium               Tier 3  1549.733966    3
# 4        Small               Tier 1    29.807098    1
# 5        Small               Tier 2  1702.480561    2
# 38       Small               Tier 2  1832.556936    2

# %%
sns.scatterplot(data=mart, x='Item_MRP', y='Sales')
# Out:
# <Axes: xlabel='Item_MRP', ylabel='Sales'>
