# %%
# Import library
import matplotlib.pyplot as plt
import numpy as np

# %%
# membuat data dumb

X = [1,2,3,4,5]
y = [5,20,10,13,17]

plt.grid(axis="y",
        linewidth=2,
        linestyle="dashed",
        color="lightgray")

plt.plot(X,y)
plt.xticks(X)
plt.show()
