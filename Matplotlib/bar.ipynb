# %%
# Import library
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt

kategori = ["mie", "nasi", "kue", "cabai"]
nilai = [23, 45, 12, 36]

plt.bar(kategori, nilai, color="skyblue")

# jika ingin visual bar nya horizontal 
# plt.barh(kategori, nilai, color="skyblue")

plt.title("Perbandingan Nilai per Kategori")
plt.xlabel("Makanan")
plt.ylabel("Quantity")

plt.show()
