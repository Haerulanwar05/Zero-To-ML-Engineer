# %% [markdown]
# # Merging & Concetenating Data

# %%
# Import Library

import pandas as pd

# %%
# Load Dataset bios

bios = pd.read_csv('data/bios.csv')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
# Load Dataset ke-2 
nocs = pd.read_csv('data/noc_regions.csv')
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
# merge Dataframe 
bios_new = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='left')

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y  region notes
# 0  1960-10-02   FRA  France   NaN
# 1         NaN   FRA  France   NaN
# 2  1994-07-17   FRA  France   NaN
# 3  1978-03-20   FRA  France   NaN
# ...

# %%
# rename kolom 'region' dengan 'born_country_full

bios_new.rename(columns={'region':'born_country_full'}, inplace=True)

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y born_country_full notes
# 0  1960-10-02   FRA            France   NaN
# 1         NaN   FRA            France   NaN
# 2  1994-07-17   FRA            France   NaN
# ...

# %% [markdown]
# di dalam sebuah dataframe baru 'bios_new' hasil dari merging terdapat kolom yang bernama NOC_x dan NOC_y, ini terjadi karena di dalam kedua Dataframe ini terdapat Kolom yang Sama namun dengan isi yang berbeda.

# %%
# kita ingin mengubah sebuah nama kolom NOC_x dan NOC_y dengan sufixes

# bios_new = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='left', suffixes=["bios","nocdf"])

# %%
# melihat sebuah data dimana NOC_x tidak sama dengan Born Country Full
bios_new[bios_new['NOC_x'] != bios_new['born_country_full']][['name','NOC_x','born_country_full']]
# Out:
#                        name    NOC_x born_country_full
# 4              Albert Canet   France                UK
# 12                J. Defert   France               NaN
# 13           Étienne Durand   France               NaN
# 16               Guy Forget   France           Morocco
# 27       Guy, Baron Lejeune   France               NaN
# ...                     ...      ...               ...
# 145491        Matthew Wepke  Jamaica               NaN
# 145493   Landysh Falyakhova      ROC            Russia
# 145495    Polina Luchnikova      ROC            Russia
# 145496  Valeriya Merkusheva      ROC            Russia
# 145497      Yuliya Smirnova      ROC            Russia
#
# [73210 rows x 3 columns]

# %%
# contoh concatenate

# hanya mengambil bio athlete dari USA saja
USA = bios[bios['born_country'] == "USA"].copy()

# hanya mengambil bio athlete dari gbr saja
GBR = bios[bios['born_country'] == "GBR"].copy()

# %%
USA.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country            NOC  height_cm  weight_kg   died_date
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN

# %%
USA.tail()
# Out:
#         athlete_id               name   born_date      born_city  born_region  \
# 145445      149168     Kristen Santos  1994-11-02      Fairfield  Connecticut
# 145446      149169   Corinne Stoddard  2001-08-15        Seattle   Washington
# 145454      149180      Anna Hoffmann  2000-03-28        Madison    Wisconsin
# 145457      149183     Alix Wilkinson  2000-08-02  Mammoth Lakes   California
# 145468      149195  Justin Abdelkader  1987-02-25       Muskegon     Michigan
#
#        born_country            NOC  height_cm  weight_kg died_date
# 145445          USA  United States        NaN        NaN       NaN
# 145446          USA  United States        NaN        NaN       NaN
# 145454          USA  United States        NaN        NaN       NaN
# 145457          USA  United States        NaN        NaN       NaN
# 145468          USA  United States      187.0       97.0       NaN

# %%
GBR.head()
# Out:
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country            NOC  height_cm  weight_kg   died_date
# 4           GBR         France        NaN        NaN  1930-07-25
# 37          GBR  Great Britain        NaN        NaN  1947-05-26
# 38          GBR  Great Britain        NaN        NaN  1972-05-10
# 39          GBR  Great Britain        NaN        NaN  1970-02-22
# 40          GBR  Great Britain      175.0       64.0         NaN

# %%
GBR.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                  NOC  height_cm  weight_kg died_date
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN

# %%
new_df = pd.concat([USA,GBR])       # menyambungkan Dataframe by defaul kiri = atas, kanan = bawah)

# %%
new_df
# Out:
#         athlete_id                name   born_date         born_city  \
# 54              55       Monique Javer  1967-07-22        Burlingame
# 960            964    Xóchitl Escobedo  1968-09-17       West Covina
# 961            965   Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238      Bert Schneider  1897-07-01         Cleveland
# 1345          1352          Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                 ...         ...               ...
# 144811      148512  Benjamin Alexander  1983-05-08            London
# 144815      148517       Ashley Watson  1993-10-28      Peterborough
# 145005      148716     Peder Kongshaug  2001-08-13         Wimbledon
# 145319      149041          Axel Brown  1992-04-02         Harrogate
# 145388      149111      Jean-Luc Baker  1993-10-07           Burnley
#
#        born_region born_country                  NOC  height_cm  weight_kg  \
# ...

# %%
# load Dataframe result 
result = pd.read_parquet('data/results.parquet')

# %%
result.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
# merge df result,bios dimana jangkar nya yaitu athlete_id

# kita ingin mengetahui info hasil dari suatu athlete baik penting atau tidak nya pertandingan itu.
combined_df = pd.merge(result,bios, on='athlete_id', how='left')

# %%
combined_df.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal  \
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None
#
#                     name   born_date born_city born_region born_country  \
# 0  Jean-François Blanchy  1886-12-12  Bordeaux     Gironde          FRA
# ...

# %% [markdown]
# # Praktek

# %%
# challenge 1

# membuat sebuah dataframe baru dimana hanya athlete indonesia saja 

INA = bios[bios['born_country'] == "INA"].copy()

# membuat sebuah dataframe baru dimana hanya athlete malaysia saja 

MAS = bios[bios['born_country'] == "MAS"].copy()

# %%
INA.head()
# Out:
#      athlete_id                     name   born_date   born_city  \
# 232         233             Yayuk Basuki  1970-11-30  Yogyakarta
# 233         234  Rossy Pratiwi Dipoyanti  1972-06-28     Bandung
# 234         235                 Finarsih  1972-02-08      Sleman
# 235         236        Ling Ling Agustin  1969-08-23      Kediri
# 238         239            Zelin Resiana  1972-07-09    Magelang
#
#                     born_region born_country        NOC  height_cm  weight_kg  \
# 232  Daerah Istimewa Yogyakarta          INA  Indonesia      165.0       55.0
# 233                  Jawa Barat          INA  Indonesia        NaN        NaN
# 234                 Jawa Tengah          INA  Indonesia        NaN        NaN
# 235                  Jawa Timur          INA  Indonesia        NaN        NaN
# 238                 Jawa Tengah          INA  Indonesia      169.0       58.0
#
#     died_date
# 232       NaN
# 233       NaN
# 234       NaN
# 235       NaN
# 238       NaN

# %%
INA.tail()
# Out:
#         athlete_id                     name   born_date   born_city  \
# 140211      143712         Jonatan Christie  1997-09-15     Jakarta
# 140212      143713  Kevin Sanjaya Sukamuljo  1995-08-02  Banyuwangi
# 140213      143714   Marcus Fernaldi Gideon  1991-03-09     Jakarta
# 140215      143716            Aflah Prawira  1997-11-13     Cirebon
# 140216      143717          Rahmat Abdullah  2000-10-13    Makassar
#
#                           born_region born_country        NOC  height_cm  \
# 140211  Daerah Khusus Ibukota Jakarta          INA  Indonesia        NaN
# 140212                     Jawa Timur          INA  Indonesia        NaN
# 140213  Daerah Khusus Ibukota Jakarta          INA  Indonesia        NaN
# 140215                     Jawa Barat          INA  Indonesia        NaN
# 140216               Sulawesi Selatan          INA  Indonesia        NaN
#
#         weight_kg died_date
# 140211        NaN       NaN
# 140212        NaN       NaN
# 140213        NaN       NaN
# ...

# %%
MAS.head()
# Out:
#      athlete_id                name   born_date born_city   born_region  \
# 950         954      Cheah Soon Kit  1968-01-09      Ipoh         Perak
# 952         956        Ong Ewe Hock  1972-03-14    Penang  Pulau Pinang
# 953         957  Alan Sidek Mohamed  1963-11-10   Banting      Selangor
# 954         958  Ajib Sidek Mohamed  1968-07-08   Banting      Selangor
# 958         962        Yap Kim Hock  1970-07-02      Muar         Johor
#
#     born_country       NOC  height_cm  weight_kg died_date
# 950          MAS  Malaysia      180.0       73.0       NaN
# 952          MAS  Malaysia      163.0       55.0       NaN
# 953          MAS  Malaysia      178.0       69.0       NaN
# 954          MAS  Malaysia      180.0       68.0       NaN
# 958          MAS  Malaysia      160.0       60.0       NaN

# %%
MAS.tail()
# Out:
#         athlete_id                        name   born_date         born_city  \
# 132242      135093                  Welson Sim  1997-03-29           Kuching
# 132243      135094  Mohammad Hafifi bin Mansor  1990-10-28  Kuala Terengganu
# 134593      137673                Jeffrey Webb  1998-10-27      Kuala Lumpur
# 134594      137674                  Julian Yee  1997-05-26      Kuala Lumpur
# 135271      138434                P. Alagendra  1929-07-23            Kajang
#
#          born_region born_country       NOC  height_cm  weight_kg died_date
# 132242       Sarawak          MAS  Malaysia      181.0       70.0       NaN
# 132243    Terengganu          MAS  Malaysia      166.0       69.0       NaN
# 134593  Kuala Lumpur          MAS  Malaysia      173.0       65.0       NaN
# 134594  Kuala Lumpur          MAS  Malaysia      166.0       60.0       NaN
# 135271      Selangor          MAS    Malaya        NaN        NaN       NaN

# %%
# Satukan kedua tabel tersebut secara vertikal menjadi satu DataFrame baru bernama df_asean.

df_asean = pd.concat([INA,MAS])

# %%
df_asean
# Out:
#         athlete_id                        name   born_date         born_city  \
# 232            233                Yayuk Basuki  1970-11-30        Yogyakarta
# 233            234     Rossy Pratiwi Dipoyanti  1972-06-28           Bandung
# 234            235                    Finarsih  1972-02-08            Sleman
# 235            236           Ling Ling Agustin  1969-08-23            Kediri
# 238            239               Zelin Resiana  1972-07-09          Magelang
# ...            ...                         ...         ...               ...
# 132242      135093                  Welson Sim  1997-03-29           Kuching
# 132243      135094  Mohammad Hafifi bin Mansor  1990-10-28  Kuala Terengganu
# 134593      137673                Jeffrey Webb  1998-10-27      Kuala Lumpur
# 134594      137674                  Julian Yee  1997-05-26      Kuala Lumpur
# 135271      138434                P. Alagendra  1929-07-23            Kajang
#
# ...
