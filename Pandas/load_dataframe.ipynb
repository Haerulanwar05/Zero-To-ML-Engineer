# %% [markdown]
# # Memuat sebuah DataFrame dari File CSV

# %%
import pandas as pd

# %%
coffe = pd.read_csv('data/coffee.csv') # memuat sebuah dataframe dari file csv

# %%
coffe.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %% [markdown]
# ## memuat sebuah dataframe dari file selain csv

# %%
# memuat sebuah DataFrame dari file parquet
result_parquet = pd.read_parquet('data/results.parquet')

# %%
result_parquet.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
result_parquet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
# memuat file feather 
result_feather = pd.read_feather('data/results.feather')
result_feather.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
# memuat file xlsx
result_xlsx = pd.read_excel('data/olympics-data.xlsx', sheet_name='results') # mengakses sebuah file excel khusus nya di sheet results

# %%
result_xlsx.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
# parquet cocok untuk speed read
# csv cocok untuk biasanya universal
# excel cocok untuk multisheet

# %% [markdown]
# # Praktek

# %%
# challenge 1
# membua sebuah data dictionary
aktivitas_trade = {
    "Hari": ["Senin", "Selasa", "Rabu", "Kamis", "Jumat"],
    "Cangkir_kopi" : [2,3,1,5,2],
    "Profit_USD" : [50,-20,100,45,-10]
}

# mengubah sebuah dictionary menjadi dataframe
df_haerul = pd.DataFrame(aktivitas_trade)

df_haerul.to_csv("data/df_haerul.csv", index=False)

# %%
df_haerul
# Out:
#      Hari  Cangkir_kopi  Profit_USD
# 0   Senin             2          50
# 1  Selasa             3         -20
# 2    Rabu             1         100
# 3   Kamis             5          45
# 4   Jumat             2         -10

# %%
del aktivitas_trade # menghapus sebuah variabel aktivitas_trade

# %%
# memuat data format csv
aktivitas_trade = pd.read_csv("data/df_haerul.csv")

# menampilkan 3 data pertama
aktivitas_trade.head(3)
# Out:
#      Hari  Cangkir_kopi  Profit_USD
# 0   Senin             2          50
# 1  Selasa             3         -20
# 2    Rabu             1         100

# %%
# Membuat file dengan pemisah Tab
with open('data_rahasia.txt', 'w') as f:
    f.write("Aset\tSignal\tPrice\nBTC\tBUY\t65000\nETH\tSELL\t3500\nSOL\tHOLD\t140")

# %%
data_rahasia = pd.read_csv("data_rahasia.txt", sep="\t")

# %%
data_rahasia
# Out:
#   Aset Signal  Price
# 0  BTC    BUY  65000
# 1  ETH   SELL   3500
# 2  SOL   HOLD    140
